# %%
nota1 = 5
nota2 = 5

nota3 = nota1 + nota2

print(nota3)
# Out:
# 10

# %%
nota4 = nota1 - 3

print(nota4)
# Out:
# 2

# %%
nota5 = float(input('Valor 1: '))
nota6 = int(input('Valor 2: '))

total = nota5 ** nota6

print('% .2f' % total)
# Out:
# Valor 1: 50
# Valor 2: 1
#  50.00

# %%
x = int(input('Digite valor 1: '))
y = int(input('Digite valor 2: '))
s = x ^ y
print(s)
# Out:
# Digite valor 1: 10
# Digite valor 2: 5
# 15

# %%
x = 1
y = 2
y != x
# Out:
# True

# %%
s = x == y
not(s)
# Out:
# True

# %%
x = 3
y = 3
print( x <= y or x != y)
# Out:
# True

# %%
x = 3
y = 3
print(not(y == x))
# Out:
# False

# %%
x = 'Feliphe'
y = 'Araujo'
len(x)
# Out:
# 7

# %%
nome = 'Feliphe'
sobrenome = ' Santos'
nome_comp = nome + sobrenome
print(nome_comp)
# Out:
# Feliphe Santos

# %%
nome[0]
# Out:
# 'F'

# %%
x = 'ambrosio'
x[0:3]
# Out:
# 'amb'

# %%
nome = input('Digite seu nome: ')
saldo = 57.45
print('Olá,' ,nome, ' seu saldo é: R$',saldo,)
# Out:
# Digite seu nome: Feliphe
# Olá, Feliphe  seu saldo é: R$ 57.45

# %%
a = 'gustavo'
b = ' willam'
print( a +  b )
# Out:
# gustavo willam

# %%
print(a[0])
# Out:
# g

# %%
nome = input('Boa tarde, por gentileza informe seu nome: ')
idade = input('Boa tarde informe sua idade: ')
altura = float(input('Informe sua altura em metros: '))
peso = float(input('informe seu peso em kg: '))
IMC = peso / altura ** 2
print(nome, ',Seu IMC é: %.2f' % IMC,)
# Out:
# Boa tarde, por gentileza informe seu nome: Feliphe
# Boa tarde informe sua idade: 19
# Informe sua altura em metros: 1.67
# informe seu peso em kg: 50
# Feliphe ,Seu IMC é: 17.93

# %%
nome = '0123456789'
print(nome[0:9])
# Out:
# 012345678

# %%
nome = 'Michael Douglas'
not('Michael'in(nome))
# Out:
# False

# %%
nome = 'Michael Dougglas'
nome.startswith('Michael')
# Out:
# True

# %%
nome = 'Feliphe'
nome.upper()
# Out:
# 'FELIPHE'

# %%
nome.lower()
# Out:
# 'feliphe'

# %%
nome = 'feliphe'
nome.islower()
# Out:
# True

# %%
nome.isupper()
# Out:
# False

# %%
nome.upper()
# Out:
# 'FELIPHE'

# %%
nome.isupper()
# Out:
# False

# %%
nome = 'FELIPE'
nome.isupper()
# Out:
# True

# %%
nome.count('E')
# Out:
# 2

# %%
nome.find('2')
# Out:
# -1

# %%
t = ('um tigre, dois tigres, três tigres')
t.find("dois")
# Out:
# 10

# %%
t[0:11]
# Out:
# 'um tigre, d'

# %%
t.find('tigre')
# Out:
# 3

# %%
t.rfind('tigre')
# Out:
# 28

# %%
t.split(",")
# Out:
# ['um tigre', ' dois tigres', ' três tigres']

# %%
t.split(' ')
# Out:
# ['um', 'tigre,', 'dois', 'tigres,', 'três', 'tigres']

# %%
t.replace('gato','tigre')
# Out:
# 'um tigre, dois tigres, três tigres'

# %%
t.replace('tigre','gato')
# Out:
# 'um gato, dois gatos, três gatos'

# %%
t = '   Olá    '
t.strip()
# Out:
# 'Olá'

# %%
t = '   olá  '
t.lstrip() # left = esquerda
# Out:
# 'olá  '

# %%
t.rstrip() # right = direita
# Out:
# '   olá'

# %%
frase= 'um tigre, dois tigres, três tigres'
len(frase)
# Out:
# 34

# %%
nom = input("Digite seu nome: ")
print('Olá ' + nom + ', bem vindo ao Phyton!')
# Out:
# Digite seu nome: luiz otávio araújo
# Olá luiz otávio araújo, bem vindo ao Phyton!
